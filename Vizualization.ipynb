# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Line plots

# %%
yield_apples = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931]

# %%
plt.plot(yield_apples)
plt.show()

# %%
#Customizing the x-axis
years = [2010, 2011, 2012, 2013, 2014, 2015]
yield_apples = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931]

plt.plot(years, yield_apples,c='green')
plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)')
plt.show()

# %% [markdown]
# #### Plotting multiple lines

# %%
years = range(2000, 2012)
apples = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931, 0.934, 0.936, 0.937, 0.9375, 0.9372, 0.939]
oranges = [0.962, 0.941, 0.930, 0.923, 0.918, 0.908, 0.907, 0.904, 0.901, 0.898, 0.9, 0.896 ]

plt.plot(years, apples)
plt.plot(years, oranges)
plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)')
plt.show()

# %%
#adding chart titles and legends

plt.plot(years, apples)
plt.plot(years, oranges)

plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)')

plt.title("Crop Yields in MH",size=15)
plt.legend(['Apples', 'Oranges']);
plt.show()

# %% [markdown]
# You can find the full list of marker types here: https://matplotlib.org/3.1.1/api/markers_api.html .

# %%
plt.plot(years, apples, marker='s', c='b', ls='--', lw=2)
plt.plot(years, oranges, marker='o', c='r', ls='--', lw=2)

plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)')

plt.title("Crop Yields in Kanto")
plt.legend(['Apples', 'Oranges'])
plt.show()

# %% [markdown]
# ## Scatter Plots

# %%
# Load data into a Pandas dataframe
flowers_df = sns.load_dataset("iris")
flowers_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
plt.plot(flowers_df.sepal_length, flowers_df.sepal_width)

# %% [markdown]
# The output is not very informative as there are too many combinations of the two properties within the dataset. There doesn't seem to be simple relationship between them.

# %%
plt.figure(figsize=(8,6))

sns.scatterplot(x=flowers_df.sepal_length, y=flowers_df.sepal_width)
plt.show()

# %%
plt.scatter(flowers_df['sepal_length'],flowers_df['sepal_width'])
plt.show()

# %%
#We can color the dots using the flower species as a hue.
#We can also make the points larger using the s argument.
plt.figure(figsize=(12, 6))

sns.scatterplot(x=flowers_df.sepal_length, 
                y=flowers_df.sepal_width,
                hue=flowers_df.species, s=50)
plt.title('Sepal Dimensions')
# Out:
# Text(0.5, 1.0, 'Sepal Dimensions')

# %% [markdown]
# ## Histograms

# %%
sns.set_style("darkgrid")

# %%
plt.figure(figsize=(8,6))

plt.hist(flowers_df.sepal_width)
plt.title("Distribution of Sepal Width")
plt.show()

# %% [markdown]
# We can immediately see that the sepal widths lie in the range 2.0 - 4.5, and around 35
# values are in the range 2.9 - 3.1, which seems to be the most populous bin.

# %%
#Controlling the size and number of bins
plt.figure(figsize=(8,4))
# Specifying the number of bins
plt.hist(flowers_df.sepal_width, bins=15)
plt.show()

# %%
import numpy as np
plt.figure(figsize=(8,6))
# Specifying the boundaries of each bin
plt.hist(flowers_df.sepal_width, bins=np.arange(2, 5, 0.25))

# %%
#multiple histograms
setosa_df = flowers_df[flowers_df.species == 'setosa']
versicolor_df = flowers_df[flowers_df.species == 'versicolor']

plt.figure(figsize=(6,8))
plt.hist(setosa_df.sepal_width, alpha=0.2, bins=np.arange(2, 5, 0.25))
plt.hist(versicolor_df.sepal_width, alpha=0.4, bins=np.arange(2, 5, 0.25))
plt.show()

# %% [markdown]
# ## Bar Charts

# %%
years = range(2000, 2006)
apples = [0.35, 0.6, 0.9, 0.8, 0.65, 0.8]
oranges = [0.4, 0.8, 0.9, 0.7, 0.6, 0.8]

# %%
plt.bar(years, oranges)
plt.show()

# %%
#Like histograms, we can stack bars on top of one another.

plt.bar(years, apples)
plt.bar(years, oranges, bottom=apples)
plt.show()
